# %%
from pyfm import pylibfm
import pandas as pd 
import numpy as np
import math
from sklearn.feature_extraction import DictVectorizer
from implementations import *

# %%
df_train = load_data("data_train.csv")
df_predict = load_data("data_test.csv")

# %%
split_ratio = 0.8
#train,test = split(df,split_ratio)
train_actual = df_train
predict = df_predict

# %%
#train_data,y_train = create_input_pyfm(train)
#test_data,y_test = create_input_pyfm(test)
predict_data,y_predict = create_input_pyfm(predict)
train_actual_data,y_train_actual = create_input_pyfm(train_actual)

# %%
v = DictVectorizer()
X_train = v.fit_transform(train_actual_data)
X_test = v.transform(predict_data)

# %%
# Hyperparameters

num_factors = 20
num_iter = 200
task = 'regression'
initial_learning_rate = 0.001
learning_rate_schedule = 'optimal'

# %%
fm = pylibfm.FM(num_factors=num_factors, num_iter=num_iter, task=task,
                    initial_learning_rate=initial_learning_rate,
                    learning_rate_schedule=learning_rate_schedule)

# %%
fm.fit(X_train, y_train_actual)
# Out:
# Creating validation dataset of 0.01 of training for adaptive regularization
# -- Epoch 1
# Training MSE: 0.54279
# -- Epoch 2
# Training MSE: 0.51076
# -- Epoch 3
# Training MSE: 0.50237
# -- Epoch 4
# Training MSE: 0.49777
# -- Epoch 5
# Training MSE: 0.49486
# -- Epoch 6
# Training MSE: 0.49276
# -- Epoch 7
# Training MSE: 0.49113
# -- Epoch 8
# Training MSE: 0.48980
# -- Epoch 9
# Training MSE: 0.48858
# -- Epoch 10
# Training MSE: 0.48745
# -- Epoch 11
# Training MSE: 0.48638
# -- Epoch 12
# Training MSE: 0.48530
# -- Epoch 13
# Training MSE: 0.48413
# -- Epoch 14
# Training MSE: 0.48300
# -- Epoch 15
# Training MSE: 0.48178
# -- Epoch 16
# Training MSE: 0.48046
# -- Epoch 17
# Training MSE: 0.47913
# -- Epoch 18
# Training MSE: 0.47777
# -- Epoch 19
# Training MSE: 0.47629
# -- Epoch 20
# Training MSE: 0.47478
# -- Epoch 21
# Training MSE: 0.47322
# -- Epoch 22
# Training MSE: 0.47163
# -- Epoch 23
# Training MSE: 0.47006
# -- Epoch 24
# Training MSE: 0.46848
# -- Epoch 25
# Training MSE: 0.46690
# -- Epoch 26
# Training MSE: 0.46537
# -- Epoch 27
# Training MSE: 0.46392
# -- Epoch 28
# Training MSE: 0.46252
# -- Epoch 29
# Training MSE: 0.46117
# -- Epoch 30
# Training MSE: 0.45994
# -- Epoch 31
# Training MSE: 0.45881
# -- Epoch 32
# Training MSE: 0.45772
# -- Epoch 33
# Training MSE: 0.45670
# -- Epoch 34
# Training MSE: 0.45578
# -- Epoch 35
# Training MSE: 0.45484
# -- Epoch 36
# Training MSE: 0.45396
# -- Epoch 37
# Training MSE: 0.45308
# -- Epoch 38
# Training MSE: 0.45218
# -- Epoch 39
# Training MSE: 0.45137
# -- Epoch 40
# Training MSE: 0.45053
# -- Epoch 41
# Training MSE: 0.44972
# -- Epoch 42
# Training MSE: 0.44899
# -- Epoch 43
# Training MSE: 0.44832
# -- Epoch 44
# Training MSE: 0.44760
# -- Epoch 45
# Training MSE: 0.44701
# -- Epoch 46
# Training MSE: 0.44641
# -- Epoch 47
# Training MSE: 0.44589
# -- Epoch 48
# Training MSE: 0.44530
# -- Epoch 49
# Training MSE: 0.44487
# -- Epoch 50
# Training MSE: 0.44434
# -- Epoch 51
# Training MSE: 0.44391
# -- Epoch 52
# Training MSE: 0.44351
# -- Epoch 53
# Training MSE: 0.44308
# -- Epoch 54
# Training MSE: 0.44268
# -- Epoch 55
# Training MSE: 0.44230
# -- Epoch 56
# Training MSE: 0.44201
# -- Epoch 57
# Training MSE: 0.44161
# -- Epoch 58
# Training MSE: 0.44132
# -- Epoch 59
# Training MSE: 0.44101
# -- Epoch 60
# Training MSE: 0.44068
# -- Epoch 61
# Training MSE: 0.44036
# -- Epoch 62
# Training MSE: 0.44012
# -- Epoch 63
# Training MSE: 0.43979
# -- Epoch 64
# Training MSE: 0.43953
# -- Epoch 65
# Training MSE: 0.43927
# -- Epoch 66
# Training MSE: 0.43899
# -- Epoch 67
# Training MSE: 0.43876
# -- Epoch 68
# Training MSE: 0.43848
# -- Epoch 69
# Training MSE: 0.43819
# -- Epoch 70
# Training MSE: 0.43798
# -- Epoch 71
# Training MSE: 0.43774
# -- Epoch 72
# Training MSE: 0.43748
# -- Epoch 73
# Training MSE: 0.43723
# -- Epoch 74
# Training MSE: 0.43703
# -- Epoch 75
# Training MSE: 0.43680
# -- Epoch 76
# Training MSE: 0.43655
# -- Epoch 77
# Training MSE: 0.43635
# -- Epoch 78
# Training MSE: 0.43614
# -- Epoch 79
# Training MSE: 0.43590
# -- Epoch 80
# Training MSE: 0.43569
# -- Epoch 81
# Training MSE: 0.43551
# -- Epoch 82
# Training MSE: 0.43529
# -- Epoch 83
# Training MSE: 0.43511
# -- Epoch 84
# Training MSE: 0.43488
# -- Epoch 85
# Training MSE: 0.43472
# -- Epoch 86
# Training MSE: 0.43449
# -- Epoch 87
# Training MSE: 0.43438
# -- Epoch 88
# Training MSE: 0.43420
# -- Epoch 89
# Training MSE: 0.43404
# -- Epoch 90
# Training MSE: 0.43385
# -- Epoch 91
# Training MSE: 0.43373
# -- Epoch 92
# Training MSE: 0.43354
# -- Epoch 93
# Training MSE: 0.43343
# -- Epoch 94
# Training MSE: 0.43326
# -- Epoch 95
# Training MSE: 0.43315
# -- Epoch 96
# Training MSE: 0.43300
# -- Epoch 97
# Training MSE: 0.43287
# -- Epoch 98
# Training MSE: 0.43276
# -- Epoch 99
# Training MSE: 0.43260
# -- Epoch 100
# Training MSE: 0.43250
# -- Epoch 101
# Training MSE: 0.43237
# -- Epoch 102
# Training MSE: 0.43225
# -- Epoch 103
# Training MSE: 0.43215
# -- Epoch 104
# Training MSE: 0.43205
# -- Epoch 105
# Training MSE: 0.43193
# -- Epoch 106
# Training MSE: 0.43179
# -- Epoch 107
# Training MSE: 0.43171
# -- Epoch 108
# Training MSE: 0.43156
# -- Epoch 109
# Training MSE: 0.43146
# -- Epoch 110
# Training MSE: 0.43136
# -- Epoch 111
# Training MSE: 0.43128
# -- Epoch 112
# Training MSE: 0.43115
# -- Epoch 113
# Training MSE: 0.43106
# -- Epoch 114
# Training MSE: 0.43098
# -- Epoch 115
# Training MSE: 0.43088
# -- Epoch 116
# Training MSE: 0.43078
# -- Epoch 117
# Training MSE: 0.43071
# -- Epoch 118
# Training MSE: 0.43057
# -- Epoch 119
# Training MSE: 0.43048
# -- Epoch 120
# Training MSE: 0.43035
# -- Epoch 121
# Training MSE: 0.43032
# -- Epoch 122
# Training MSE: 0.43020
# -- Epoch 123
# Training MSE: 0.43011
# -- Epoch 124
# Training MSE: 0.43002
# -- Epoch 125
# Training MSE: 0.42995
# -- Epoch 126
# Training MSE: 0.42987
# -- Epoch 127
# Training MSE: 0.42979
# -- Epoch 128
# Training MSE: 0.42968
# -- Epoch 129
# Training MSE: 0.42962
# -- Epoch 130
# Training MSE: 0.42950
# -- Epoch 131
# Training MSE: 0.42944
# -- Epoch 132
# Training MSE: 0.42931
# -- Epoch 133
# Training MSE: 0.42929
# -- Epoch 134
# Training MSE: 0.42918
# -- Epoch 135
# Training MSE: 0.42912
# -- Epoch 136
# Training MSE: 0.42901
# -- Epoch 137
# Training MSE: 0.42897
# -- Epoch 138
# Training MSE: 0.42887
# -- Epoch 139
# Training MSE: 0.42876
# -- Epoch 140
# Training MSE: 0.42869
# -- Epoch 141
# Training MSE: 0.42866
# -- Epoch 142
# Training MSE: 0.42856
# -- Epoch 143
# Training MSE: 0.42850
# -- Epoch 144
# Training MSE: 0.42842
# -- Epoch 145
# Training MSE: 0.42841
# -- Epoch 146
# Training MSE: 0.42828
# -- Epoch 147
# Training MSE: 0.42822
# -- Epoch 148
# Training MSE: 0.42818
# -- Epoch 149
# Training MSE: 0.42810
# -- Epoch 150
# Training MSE: 0.42799
# -- Epoch 151
# Training MSE: 0.42796
# -- Epoch 152
# Training MSE: 0.42790
# -- Epoch 153
# Training MSE: 0.42782
# -- Epoch 154
# Training MSE: 0.42778
# -- Epoch 155
# Training MSE: 0.42776
# -- Epoch 156
# Training MSE: 0.42766
# -- Epoch 157
# Training MSE: 0.42762
# -- Epoch 158
# Training MSE: 0.42754
# -- Epoch 159
# Training MSE: 0.42750
# -- Epoch 160
# Training MSE: 0.42745
# -- Epoch 161
# Training MSE: 0.42742
# -- Epoch 162
# Training MSE: 0.42736
# -- Epoch 163
# Training MSE: 0.42728
# -- Epoch 164
# Training MSE: 0.42723
# -- Epoch 165
# Training MSE: 0.42723
# -- Epoch 166
# Training MSE: 0.42714
# -- Epoch 167
# Training MSE: 0.42707
# -- Epoch 168
# Training MSE: 0.42710
# -- Epoch 169
# Training MSE: 0.42699
# -- Epoch 170
# Training MSE: 0.42694
# -- Epoch 171
# Training MSE: 0.42690
# -- Epoch 172
# Training MSE: 0.42682
# -- Epoch 173
# Training MSE: 0.42681
# -- Epoch 174
# Training MSE: 0.42674
# -- Epoch 175
# Training MSE: 0.42678
# -- Epoch 176
# Training MSE: 0.42667
# -- Epoch 177
# Training MSE: 0.42663
# -- Epoch 178
# Training MSE: 0.42661
# -- Epoch 179
# Training MSE: 0.42653
# -- Epoch 180
# Training MSE: 0.42644
# -- Epoch 181
# Training MSE: 0.42641
# -- Epoch 182
# Training MSE: 0.42641
# -- Epoch 183
# Training MSE: 0.42638
# -- Epoch 184
# Training MSE: 0.42631
# -- Epoch 185
# Training MSE: 0.42631
# -- Epoch 186
# Training MSE: 0.42621
# -- Epoch 187
# Training MSE: 0.42620
# -- Epoch 188
# Training MSE: 0.42618
# -- Epoch 189
# Training MSE: 0.42610
# -- Epoch 190
# Training MSE: 0.42605
# -- Epoch 191
# Training MSE: 0.42602
# -- Epoch 192
# Training MSE: 0.42597
# -- Epoch 193
# Training MSE: 0.42591
# -- Epoch 194
# Training MSE: 0.42589
# -- Epoch 195
# Training MSE: 0.42582
# -- Epoch 196
# Training MSE: 0.42578
# -- Epoch 197
# Training MSE: 0.42574
# -- Epoch 198
# Training MSE: 0.42568
# -- Epoch 199
# Training MSE: 0.42566
# -- Epoch 200
# Training MSE: 0.42561

# %%
preds = fm.predict(X_test)
df_return = predict.copy()
df_return.Rating = (np.round(preds)).astype(int)

# %%
df_return.Rating = (np.round(preds)).astype(int)

# %%
df_return
# Out:
#          User  Movie  Rating
# 0          37      1       3
# 1          73      1       3
# 2         156      1       4
# 3         160      1       3
# 4         248      1       3
# 5         256      1       3
# 6         284      1       3
# 7         400      1       4
# 8         416      1       4
# 9         456      1       4
# 10        474      1       3
# 11        495      1       3
# 12        515      1       2
# 13        518      1       4
# 14        521      1       4
# 15        559      1       3
# 16        596      1       3
# 17        614      1       4
# 18        621      1       3
# 19        661      1       4
# 20        697      1       3
# 21        710      1       3
# 22        713      1       3
# 23        732      1       4
# 24        807      1       3
# 25        824      1       4
# 26        926      1       3
# 27        951      1       3
# 28       1000      1       4
# 29       1141      1       4
# ...       ...    ...     ...
# 1176922  9786   1000       4
# 1176923  9791   1000       4
# 1176924  9797   1000       4
# 1176925  9799   1000       4
# 1176926  9801   1000       4
# 1176927  9809   1000       4
# 1176928  9814   1000       3
# 1176929  9817   1000       4
# 1176930  9823   1000       4
# 1176931  9830   1000       3
# 1176932  9831   1000       3
# 1176933  9836   1000       4
# 1176934  9851   1000       4
# 1176935  9862   1000       4
# 1176936  9880   1000       4
# 1176937  9885   1000       4
# 1176938  9889   1000       4
# 1176939  9896   1000       3
# 1176940  9901   1000       4
# 1176941  9924   1000       3
# 1176942  9928   1000       4
# 1176943  9930   1000       4
# 1176944  9939   1000       4
# 1176945  9941   1000       4
# 1176946  9965   1000       4
# 1176947  9974   1000       4
# 1176948  9977   1000       4
# 1176949  9978   1000       3
# 1176950  9982   1000       3
# 1176951  9996   1000       4
#
# [1176952 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = mean_squared_error(y_test,preds)

# %%
evaluate(df_return,test)
# Out:
# 1.001951302245724

# %%
rmse
# Out:
# 1.0039064120718806

# %%
# Out:
#          User  Movie    Rating
# 1012375  9244    799  3.657642
# 184753   5573    161  4.032447
# 507869   3368    434  4.091241
# 419309   8435    347  3.900704
# 686927   9105    588  3.698320
# 488737   8992    419  2.938936
# 1029829  1111    814  3.404924
# 273776   2829    230  4.089648
# 1058444  6427    849  3.912025
# 782466   2660    638  4.441175
# 252130   5616    210  3.545854
# 1001526  6994    791  4.177240
# 272073   3742    228  3.465639
# 671104   7799    575  3.992309
# 423589   7811    350  4.534908
# 218803   1577    184  3.133658
# 702061   4627    596  4.797727
# 38258    6899     27  3.776039
# 824879    596    660  4.658498
# 225126   1075    188  4.598402
# 360389   1225    303  4.503117
# 366494   7547    306  4.803584
# 1095282  3454    897  2.896227
# 400552   1324    327  3.576110
# 570666   4901    485  3.711665
# 1069686  6367    864  3.562346
# 775488   9694    631  3.939809
# 1133599  3629    952  3.957987
# 458579   8557    392  4.042075
# 346536   6091    295  4.549182
# ...       ...    ...       ...
# 22309    5491     14  4.380598
# 867239   2383    683  4.518232
# 743845   5665    615  4.170717
# 876728   2602    689  4.425219
# 943634    156    750  3.549570
# 586589   8649    492  4.547004
# 509208   7028    434  4.432726
# 249944    556    208  3.196816
# 470830   5631    405  3.063787
# 9951     8973      6  4.743294
# 67843    6801     56  2.581914
# 268556   4090    224  3.005468
# 755794   7246    619  4.505312
# 19938    4169     13  2.964730
# 956244   1822    763  4.168551
# 749683   8481    617  4.336205
# 642670   8592    549  3.804133
# 640990   1450    548  3.672738
# 747866   2320    617  4.055483
# 416946   8231    343  4.304640
# 979492   7070    776  3.810720
# 390614   4088    320  4.148591
# 766797   9447    625  4.035177
# 902450   7588    705  4.284544
# 251988   3525    210  3.588604
# 866242   5696    682  4.271995
# 489720   5419    420  3.649360
# 925471   9659    735  3.205220
# 310001   9419    256  4.813579
# 269352   2179    225  3.751924
#
# [235391 rows x 3 columns]

# %%
def submission_table(original_df, col_userID, col_movie, col_rate):
	""" return table according with Kaggle convention """

	def id(row):
	    return 'r' + str(int(row[col_userID])) + '_c' + str(int(row[col_movie]))

	def pred(row):
	    return row[col_rate]

	df = pd.DataFrame.copy(original_df)
	df['Id'] = df.apply(id, axis=1)
	df['Prediction'] = df.apply(pred, axis=1)

	return df[['Id', 'Prediction']]

# %%
submission = submission_table(df_return, 'User', 'Movie', 'Rating')

# %%
file_name = 'prediction_pyfm.csv'
submission.to_csv(file_name, index=False)

# %%
from pyspark.sql import SQLContext
from pyspark.mllib.recommendation import ALS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-611162bfec99> in <module>()
# ----> 1 from pyspark.sql import SQLContext
#       2 from pyspark.mllib.recommendation import ALS
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
import pickle

# %%
with open('fm_model.pkl', 'wb') as f:
    pickle.dump(fm, f)

# %%
with open('fm_model.pkl', 'rb') as f:
    fm2 = pickle.load(f)

# %%
preds2 = fm2.predict(X_test)

# %%
preds == preds2
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])
